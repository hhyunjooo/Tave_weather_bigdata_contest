# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np

warnings.filterwarnings('ignore')
plt.rc('font',family='Batang')
plt.rcParams["figure.figsize"] = (10,10)

# %%
buy_weather_total = pd.read_csv("../활용 데이터셋/buy_weather_total.csv", encoding ='cp949', parse_dates=["일시"])

# %%
buy_weather_total
# Out:
#            sm_cat         일시  qty   평균기온(°C)   최저기온(°C)   최고기온(°C)  일강수량(mm)  \
# 0           가스온수기 2018-01-13    1  -3.685828  -8.640719   2.032535  0.027833
# 1         가열식 가습기 2018-01-13    9  -3.685828  -8.640719   2.032535  0.027833
# 2         공기정화 용품 2018-01-13   61  -3.685828  -8.640719   2.032535  0.027833
# 3           공기청정기 2018-01-13   32  -3.685828  -8.640719   2.032535  0.027833
# 4         난방용 열풍기 2018-01-13    2  -3.685828  -8.640719   2.032535  0.027833
# ...           ...        ...  ...        ...        ...        ...       ...
# 23427         컨벡터 2019-09-13    1  21.101183  16.848317  26.746139  0.024606
# 23428  탁상/USB 선풍기 2019-09-13    3  21.101183  16.848317  26.746139  0.024606
# 23429        황토매트 2019-09-13    1  21.101183  16.848317  26.746139  0.024606
# 23430     휴대용 선풍기 2019-09-13    2  21.101183  16.848317  26.746139  0.024606
# 23431          히터 2019-09-13    6  21.101183  16.848317  26.746139  0.024606
#
# ...

# %% [markdown]
# ## 온도

# %% [markdown]
# ### 냉방

# %%
buy_weather_tpr = pd.read_csv("../활용 데이터셋/buy_weather_tpr.csv", encoding ='cp949', parse_dates=["일시"])

# %%
buy_weather_tpr
# Out:
#        sm_cat         일시  qty   평균기온(°C)   최저기온(°C)   최고기온(°C)       불쾌지수  \
# 0     멀티형 에어컨 2018-01-13    1  -3.685828  -8.640719   2.032535  30.903721
# 1     멀티형 에어컨 2018-01-17    2   3.906139   1.162178   7.499802  40.264687
# 2     멀티형 에어컨 2018-01-29    4  -6.496414  -9.936183  -2.337972  31.110377
# 3     멀티형 에어컨 2018-02-02    3  -2.955446  -8.610693   3.691881  35.298583
# 4     멀티형 에어컨 2018-02-06    1  -8.508964 -12.716932  -4.041833  28.178318
# ...       ...        ...  ...        ...        ...        ...        ...
# 7250  업소용 선풍기 2019-08-22   18  25.098214  22.020990  29.666931  75.455659
# 7251  업소용 선풍기 2019-08-23   17  23.778585  19.844794  28.646365  72.516224
# 7252  업소용 선풍기 2019-08-24    2  22.137205  18.337992  26.999213  70.193037
# 7253  업소용 선풍기 2019-08-27   10  22.601584  20.336310  25.648611  71.911422
# 7254  업소용 선풍기 2019-09-07    1  24.907879  21.890381  28.249499  75.028004
#
#             열지수       체감온도
# 0     17.634558  -2.978124
# ...

# %% [markdown]
# ### 난방

# %%
buy_weather_tph = pd.read_csv("../활용 데이터셋/buy_weather_tph.csv", encoding ='cp949', parse_dates=["일시"])

# %%
buy_weather_tph
# Out:
#      sm_cat         일시  qty   평균기온(°C)   최저기온(°C)   최고기온(°C)       불쾌지수  \
# 0     가스온수기 2018-01-13    1  -3.685828  -8.640719   2.032535  30.903721
# 1     가스온수기 2018-01-17    1   3.906139   1.162178   7.499802  40.264687
# 2     가스온수기 2018-01-19    1   0.716963  -3.344379   6.536884  39.199984
# 3     가스온수기 2018-01-29    2  -6.496414  -9.936183  -2.337972  31.110377
# 4     가스온수기 2018-02-02    1  -2.955446  -8.610693   3.691881  35.298583
# ...     ...        ...  ...        ...        ...        ...        ...
# 8069     히터 2019-08-23   10  23.778585  19.844794  28.646365  72.516224
# 8070     히터 2019-08-24   14  22.137205  18.337992  26.999213  70.193037
# 8071     히터 2019-08-27   11  22.601584  20.336310  25.648611  71.911422
# 8072     히터 2019-09-07    6  24.907879  21.890381  28.249499  75.028004
# 8073     히터 2019-09-13    6  21.101183  16.848317  26.746139  68.379877
#
#             열지수       체감온도
# 0     17.634558  -2.978124
# 1     32.675597   4.970363
# ...

# %% [markdown]
# ## 습도

# %%
buy_weather_hm = pd.read_csv("../활용 데이터셋/buy_weather_hm.csv", encoding ='cp949', parse_dates=["일시"])

# %%
buy_weather_hm
# Out:
#      sm_cat         일시  qty   평균기온(°C)   최저기온(°C)   최고기온(°C)       불쾌지수  \
# 0       제습기 2018-01-13    9  -3.685828  -8.640719   2.032535  30.903721
# 1       제습기 2018-01-17   21   3.906139   1.162178   7.499802  40.264687
# 2       제습기 2018-01-19   24   0.716963  -3.344379   6.536884  39.199984
# 3       제습기 2018-01-29   35  -6.496414  -9.936183  -2.337972  31.110377
# 4       제습기 2018-02-02    8  -2.955446  -8.610693   3.691881  35.298583
# ...     ...        ...  ...        ...        ...        ...        ...
# 5340   에어워셔 2019-08-23    2  23.778585  19.844794  28.646365  72.516224
# 5341   에어워셔 2019-08-24    4  22.137205  18.337992  26.999213  70.193037
# 5342   에어워셔 2019-08-27    4  22.601584  20.336310  25.648611  71.911422
# 5343   에어워셔 2019-09-07    1  24.907879  21.890381  28.249499  75.028004
# 5344   에어워셔 2019-09-13    1  21.101183  16.848317  26.746139  68.379877
#
#             열지수       체감온도
# 0     17.634558  -2.978124
# 1     32.675597   4.970363
# ...

# %% [markdown]
# ## 공기

# %%
buy_weather_ar = pd.read_csv("../활용 데이터셋/buy_weather_ar.csv", encoding ='cp949', parse_dates=["일시"])

# %%
buy_weather_ar
# Out:
#      sm_cat         일시  qty  일 미세먼지 농도(㎍/㎥)
# 0     공기청정기 2018-01-13   32       31.038462
# 1     공기청정기 2018-01-17  568       37.296296
# 2     공기청정기 2018-01-19  233       46.653846
# 3     공기청정기 2018-01-29  245       33.703704
# 4     공기청정기 2018-02-02  118       31.392857
# ...     ...        ...  ...             ...
# 1549   산림욕기 2019-06-26    1       24.291667
# 1550   산림욕기 2019-07-09    3       14.652174
# 1551   산림욕기 2019-07-11    1       10.235294
# 1552   산림욕기 2019-07-22    1       27.535714
# 1553   산림욕기 2019-08-05    1       33.333333
#
# [1554 rows x 4 columns]

# %% [markdown]
# ## 냉난방

# %%
buy_weather_tp = pd.read_csv("../활용 데이터셋/buy_weather_tp.csv", encoding ='cp949', parse_dates=["일시"])

# %%
buy_weather_tp
# Out:
#          sm_cat         일시  qty   평균기온(°C)   최저기온(°C)   최고기온(°C)       불쾌지수  \
# 0     벽걸이형 냉온풍기 2018-01-29    2  -6.496414  -9.936183  -2.337972  31.110377
# 1     벽걸이형 냉온풍기 2018-03-07    2   4.769000   0.933200   8.830600  43.206644
# 2     벽걸이형 냉온풍기 2018-03-13    1  11.290514   2.889307  18.440198  53.437619
# 3     벽걸이형 냉온풍기 2018-03-27    2  12.200593   4.460672  19.939328  54.818346
# 4     벽걸이형 냉온풍기 2018-04-19    1  13.542490   4.642262  21.921230  56.837360
# ...         ...        ...  ...        ...        ...        ...        ...
# 1199  스탠드형 냉온풍기 2019-08-23    9  23.778585  19.844794  28.646365  72.516224
# 1200  스탠드형 냉온풍기 2019-08-24   11  22.137205  18.337992  26.999213  70.193037
# 1201  스탠드형 냉온풍기 2019-08-27   16  22.601584  20.336310  25.648611  71.911422
# 1202  스탠드형 냉온풍기 2019-09-07    7  24.907879  21.890381  28.249499  75.028004
# 1203  스탠드형 냉온풍기 2019-09-13    2  21.101183  16.848317  26.746139  68.379877
#
#             열지수       체감온도
# 0     12.059606  -7.639590
# ...

# %% [markdown]
# ## LightGBM
#
# - https://smecsm.tistory.com/133
# - https://nurilee.com/2020/04/03/lightgbm-definition-parameter-tuning/
# - https://mizykk.tistory.com/102

# %% [markdown]
# ### 평가기준

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error

# %%
def MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 

def MPE(y_test, y_pred): 
    return np.mean((y_test - y_pred) / y_test) * 100

def get_rmse(model):
    global mpe
    global mape
    pred = model.predict(X_test)
    mse = mean_squared_error(y_test , pred)
    rmse = np.sqrt(mse)
    mpe = MPE(y_test,pred)
    mape = MAPE(y_test,pred)
    mae = mean_absolute_error(y_test, pred)

    r2 = r2_score(y_test, pred)
    
    print('{0} 로그 변환된 RMSE: {1}'.format(model.__class__.__name__,np.round(rmse, 3)))
    print('{0} 로그 변환된 MSE: {1}'.format(model.__class__.__name__,np.round(mse, 3)))
    print('{0} 로그 변환된 MAE: {1}'.format(model.__class__.__name__,np.round(mae, 3)))
    print('{0} 로그 변환된 MAPE: {1}'.format(model.__class__.__name__,np.round(mape, 3)))
    print('{0} 로그 변환된 MPE: {1}'.format(model.__class__.__name__,np.round(mpe, 3)))
    print('r2-score : {0:.3f}'.format(r2))
    return rmse,mse,mae,mape,mpe,r2

# %%
def get_rmses(model):
#     rmses=[]
    rmse,mse,mae,mape,mpe,r2 = get_rmse(model)
#     rmses.append(rmse)
#   tpr_eval_test= tpr_eval_test.append({'sm_cat': cg_,'model':model,'MSE': mse, 'RMSE': rmse, 'MAE':mae, 'MAPE':mape,
#                                      'MPE':mpe,'R2-score':r2}, ignore_index=True)
        
    return rmse,mse,mae,mape,mpe,r2

# %% [markdown]
# ### 함수

# %%
from sklearn.model_selection import GridSearchCV

def print_best_params(model, params):
    grid_model = GridSearchCV(model, param_grid=params, 
                              scoring='neg_mean_squared_error', cv=5)
    grid_model.fit(X_features, y_target)
    rmse = np.sqrt(-1* grid_model.best_score_)
    print('{0} 5 CV 시 최적 평균 RMSE 값: {1}, 최적 parameter:{2}'.format(model.__class__.__name__,
                                        np.round(rmse, 4), grid_model.best_params_))
    return grid_model.best_estimator_, grid_model.best_params_

# %%
from sklearn.model_selection import train_test_split

# 인자로 입력받은 DataFrame을 복사 한 뒤 Time 컬럼만 삭제하고 복사된 DataFrame 반환
def get_preprocessed_df(df=None):
    df_copy = df.copy()
    df_copy.drop(['sm_cat','일시'], axis=1, inplace=True)
    return df_copy

# %%
# 사전 데이터 가공 후 학습과 테스트 데이터 세트를 반환하는 함수.
def get_train_test_dataset(df=None):
    df = get_preprocessed_df(df)
    
    features_index = df.dtypes[df.dtypes != 'object'].index
    skew_features = df[features_index].apply(lambda x : skew(x))
    skew_features_top = skew_features[skew_features > 1]
    df[skew_features_top.index] = np.log1p(df[skew_features_top.index])
    
    X_features = df.drop('qty',axis=1, inplace=False)
    y_target = df['qty']
    X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.2, random_state=156)
    
    return X_features,y_target,X_train, X_test, y_train, y_test

# %%
ar_eval_test = pd.DataFrame(columns=['sm_cat','model','max_depth','num_leaves','min_child_samples','MSE','RMSE','MAE','MAPE',
                                      'MPE','R2-score'])

# %%
hm_eval_test = pd.DataFrame(columns=['sm_cat','model','max_depth','num_leaves','min_child_samples','MSE','RMSE','MAE','MAPE',
                                      'MPE','R2-score'])

# %%
tpr_eval_test = pd.DataFrame(columns=['sm_cat','model','max_depth','num_leaves','min_child_samples','MSE','RMSE','MAE','MAPE',
                                      'MPE','R2-score'])

# %%
tph_eval_test = pd.DataFrame(columns=['sm_cat','model','max_depth','num_leaves','min_child_samples','MSE','RMSE','MAE','MAPE',
                                      'MPE','R2-score'])

# %%
tp_eval_test = pd.DataFrame(columns=['sm_cat','model','max_depth','num_leaves','min_child_samples','MSE','RMSE','MAE','MAPE',
                                      'MPE','R2-score'])

# %% [markdown]
# ## 냉난방

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor
from scipy.stats import skew


for cg_ in ['벽걸이형 냉온풍기','스탠드형 냉온풍기']:
    buy_weather_tp_cg = buy_weather_tp[buy_weather_tp['sm_cat'] == cg_]
    
    X_features,y_target,X_train, X_test, y_train, y_test = get_train_test_dataset(buy_weather_tp_cg)
    
    lgbm_params = {'max_depth':[10,7,5,3,1],'num_leaves':[64,32,16,8,4,2],'min_child_samples':[20,15,10,5,3,1]}
    lgbm_reg = LGBMRegressor()
    best_lgbm, best_params_ = print_best_params(lgbm_reg, lgbm_params)
    
    max_depth= best_params_['max_depth']
    num_leaves= best_params_['num_leaves']
    min_child_samples= best_params_['min_child_samples'] 
    
    lgbm_reg = LGBMRegressor(max_depth=max_depth, min_child_samples= min_child_samples, num_leaves= num_leaves)
    lgbm_reg.fit(X_train, y_train)
    rmse,mse,mae,mape,mpe,r2=get_rmse(lgbm_reg)
    
    tp_eval_test= tp_eval_test.append({'sm_cat': cg_,'model':'LGBM','MSE': mse, 'RMSE': rmse, 'MAE':mae, 'MAPE':mape,
                                     'MPE':mpe,'R2-score':r2,'max_depth':max_depth, 'num_leaves':num_leaves, 'min_child_samples':min_child_samples}, ignore_index=True)
    print(cg_,'\n')
# Out:
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.5616, 최적 parameter:{'max_depth': 10, 'min_child_samples': 5, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.489
# LGBMRegressor 로그 변환된 MSE: 0.239
# LGBMRegressor 로그 변환된 MAE: 0.399
# LGBMRegressor 로그 변환된 MAPE: 37.688
# LGBMRegressor 로그 변환된 MPE: -16.253
# r2-score : 0.040
# 벽걸이형 냉온풍기
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.6645, 최적 parameter:{'max_depth': 10, 'min_child_samples': 5, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.669
# LGBMRegressor 로그 변환된 MSE: 0.447
# LGBMRegressor 로그 변환된 MAE: 0.535
# LGBMRegressor 로그 변환된 MAPE: 29.49
# LGBMRegressor 로그 변환된 MPE: -15.086
# r2-score : 0.146
# 스탠드형 냉온풍기

# %%
tp_eval_test
# Out:
#       sm_cat model max_depth num_leaves min_child_samples       MSE      RMSE  \
# 0  벽걸이형 냉온풍기  LGBM        10          2                 5  0.239044  0.488922
# 1  스탠드형 냉온풍기  LGBM        10          2                 5  0.447125  0.668674
#
#         MAE       MAPE        MPE  R2-score
# 0  0.399050  37.688443 -16.253347  0.039719
# 1  0.535359  29.490387 -15.085959  0.146258

# %%
tp_eval_test.to_csv('../활용 데이터셋/tp_eval_lgbm.csv', encoding='cp949',index=False)

# %% [markdown]
# ## 공기

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor
from scipy.stats import skew


for cg_ in ['공기청정기','공기정화 용품','산림욕기']:
    buy_weather_ar_cg = buy_weather_ar[buy_weather_ar['sm_cat'] == cg_]
    
    X_features,y_target,X_train, X_test, y_train, y_test = get_train_test_dataset(buy_weather_ar_cg)
    
    lgbm_params = {'max_depth':[10,7,5,3,1],'num_leaves':[64,32,16,8,4,2],'min_child_samples':[20,15,10,5,3,1]}
    lgbm_reg = LGBMRegressor()
    best_lgbm, best_params_ = print_best_params(lgbm_reg, lgbm_params)
    
    max_depth= best_params_['max_depth']
    num_leaves= best_params_['num_leaves']
    min_child_samples= best_params_['min_child_samples'] 
    
    lgbm_reg = LGBMRegressor(max_depth=max_depth, min_child_samples= min_child_samples, num_leaves= num_leaves)
    lgbm_reg.fit(X_train, y_train)
    rmse,mse,mae,mape,mpe,r2=get_rmse(lgbm_reg)
    
    ar_eval_test= ar_eval_test.append({'sm_cat': cg_,'model':'LGBM','MSE': mse, 'RMSE': rmse, 'MAE':mae, 'MAPE':mape,
                                     'MPE':mpe,'R2-score':r2,'max_depth':max_depth, 'num_leaves':num_leaves, 'min_child_samples':min_child_samples}, ignore_index=True)
    print(cg_,'\n')
# Out:
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.7901, 최적 parameter:{'max_depth': 10, 'min_child_samples': 3, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.754
# LGBMRegressor 로그 변환된 MSE: 0.569
# LGBMRegressor 로그 변환된 MAE: 0.595
# LGBMRegressor 로그 변환된 MAPE: 13.372
# LGBMRegressor 로그 변환된 MPE: -2.429
# r2-score : 0.400
# 공기청정기
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.5598, 최적 parameter:{'max_depth': 10, 'min_child_samples': 3, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.546
# LGBMRegressor 로그 변환된 MSE: 0.299
# LGBMRegressor 로그 변환된 MAE: 0.403
# LGBMRegressor 로그 변환된 MAPE: 8.07
# LGBMRegressor 로그 변환된 MPE: -0.961
# r2-score : 0.330
# 공기정화 용품
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.2175, 최적 parameter:{'max_depth': 10, 'min_child_samples': 3, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.113
# LGBMRegressor 로그 변환된 MSE: 0.013
# LGBMRegressor 로그 변환된 MAE: 0.098
# LGBMRegressor 로그 변환된 MAPE: 13.419
# LGBMRegressor 로그 변환된 MPE: -10.958
# r2-score : -0.558
# 산림욕기

# %%
ar_eval_test
# Out:
#     sm_cat model max_depth num_leaves min_child_samples       MSE      RMSE  \
# 0    공기청정기  LGBM        10          2                 3  0.568784  0.754178
# 1  공기정화 용품  LGBM        10          2                 3  0.298591  0.546435
# 2     산림욕기  LGBM        10          2                 3  0.012768  0.112997
#
#         MAE       MAPE        MPE  R2-score
# 0  0.594618  13.371894  -2.429373  0.400027
# 1  0.403372   8.070416  -0.960688  0.330366
# 2  0.098007  13.419462 -10.957973 -0.557630

# %% [markdown]
# ## 습도

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor
from scipy.stats import skew


for cg_ in ['제습기','초음파식 가습기','자연식 가습기','복합식 가습기','신발건조기','의류건조기','가열식 가습기','에어워셔']:
    buy_weather_hm_cg = buy_weather_hm[buy_weather_hm['sm_cat'] == cg_]
    
    X_features,y_target,X_train, X_test, y_train, y_test = get_train_test_dataset(buy_weather_hm_cg)
    
    lgbm_params = {'max_depth':[10,7,5,3,1],'num_leaves':[64,32,16,8,4,2],'min_child_samples':[20,15,10,5,3,1]}
    lgbm_reg = LGBMRegressor()
    best_lgbm, best_params_= print_best_params(lgbm_reg, lgbm_params)
    
    
    max_depth= best_params_['max_depth']
    num_leaves= best_params_['num_leaves']
    min_child_samples= best_params_['min_child_samples'] 
    
    lgbm_reg = LGBMRegressor(max_depth=max_depth, min_child_samples= min_child_samples, num_leaves= num_leaves)
    lgbm_reg.fit(X_train, y_train)
    rmse,mse,mae,mape,mpe,r2=get_rmse(lgbm_reg)
    
    hm_eval_test= hm_eval_test.append({'sm_cat': cg_,'model':'LGBM','MSE': mse, 'RMSE': rmse, 'MAE':mae, 'MAPE':mape,
                                     'MPE':mpe,'R2-score':r2,'max_depth':max_depth, 'num_leaves':num_leaves, 'min_child_samples':min_child_samples}, ignore_index=True)
    
    print(cg_,'\n')
# Out:
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.7602, 최적 parameter:{'max_depth': 10, 'min_child_samples': 5, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.719
# LGBMRegressor 로그 변환된 MSE: 0.517
# LGBMRegressor 로그 변환된 MAE: 0.576
# LGBMRegressor 로그 변환된 MAPE: 18.325
# LGBMRegressor 로그 변환된 MPE: -6.606
# r2-score : 0.399
# 제습기
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.9283, 최적 parameter:{'max_depth': 5, 'min_child_samples': 20, 'num_leaves': 64}
# LGBMRegressor 로그 변환된 RMSE: 0.834
# LGBMRegressor 로그 변환된 MSE: 0.696
# LGBMRegressor 로그 변환된 MAE: 0.688
# LGBMRegressor 로그 변환된 MAPE: 23.261
# LGBMRegressor 로그 변환된 MPE: -3.492
# r2-score : 0.683
# 초음파식 가습기
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.6825, 최적 parameter:{'max_depth': 10, 'min_child_samples': 15, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.623
# LGBMRegressor 로그 변환된 MSE: 0.388
# LGBMRegressor 로그 변환된 MAE: 0.512
# LGBMRegressor 로그 변환된 MAPE: 30.849
# LGBMRegressor 로그 변환된 MPE: -8.085
# r2-score : 0.349
# 자연식 가습기
#
# ...

# %%
hm_eval_test
# Out:
#      sm_cat model max_depth num_leaves min_child_samples       MSE      RMSE  \
# 0       제습기  LGBM        10          2                 5  0.517057  0.719067
# 1  초음파식 가습기  LGBM         5         64                20  0.696192  0.834381
# 2   자연식 가습기  LGBM        10          2                15  0.388110  0.622985
# 3   복합식 가습기  LGBM        10          8                 3  0.585168  0.764963
# 4     신발건조기  LGBM        10          2                20  0.219539  0.468549
# 5     의류건조기  LGBM        10          2                15  0.232538  0.482222
# 6   가열식 가습기  LGBM         3         64                20  0.644743  0.802959
# 7      에어워셔  LGBM        10          4                 5  0.361691  0.601408
#
#         MAE       MAPE        MPE  R2-score
# 0  0.575548  18.324754  -6.606470  0.398772
# 1  0.688335  23.261268  -3.492188  0.682995
# 2  0.511832  30.849291  -8.085131  0.348780
# 3  0.617520  23.311338  -7.393915  0.611526
# 4  0.354482  33.548749 -14.949996 -0.019232
# ...

# %% [markdown]
# ## 온도 - 냉방

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor
from scipy.stats import skew


for cg_ in ['멀티형 에어컨', '벽걸이 에어컨', '벽걸이형 선풍기', '스탠드형 에어컨', '에어컨 리모컨', '탁상/USB 선풍기',
       '휴대용 선풍기', '냉풍기', '이동형 에어컨', '중대형 에어컨', '천장형 에어컨', '에어커튼', '업소용 선풍기']:
    buy_weather_tpr_cg = buy_weather_tpr[buy_weather_tpr['sm_cat'] == cg_]
    
    X_features,y_target,X_train, X_test, y_train, y_test = get_train_test_dataset(buy_weather_tpr_cg)
  
    lgbm_params = {'max_depth':[10,7,5,3,1],'num_leaves':[64,32,16,8,4,2],'min_child_samples':[20,15,10,5,3,1]}
    lgbm_reg = LGBMRegressor()
    best_lgbm, best_params_ = print_best_params(lgbm_reg, lgbm_params)
    
    max_depth= best_params_['max_depth']
    num_leaves= best_params_['num_leaves']
    min_child_samples= best_params_['min_child_samples'] 
    
    lgbm_reg = LGBMRegressor(max_depth=max_depth, min_child_samples= min_child_samples, num_leaves= num_leaves)
    lgbm_reg.fit(X_train, y_train)
    rmse,mse,mae,mape,mpe,r2=get_rmse(lgbm_reg)
    
    tpr_eval_test= tpr_eval_test.append({'sm_cat': cg_,'model':'LGBM','MSE': mse, 'RMSE': rmse, 'MAE':mae, 'MAPE':mape,
                                     'MPE':mpe,'R2-score':r2,'max_depth':max_depth, 'num_leaves':num_leaves, 'min_child_samples':min_child_samples}, ignore_index=True)
    print(cg_,'\n')
# Out:
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 1.224, 최적 parameter:{'max_depth': 5, 'min_child_samples': 10, 'num_leaves': 8}
# LGBMRegressor 로그 변환된 RMSE: 1.199
# LGBMRegressor 로그 변환된 MSE: 1.438
# LGBMRegressor 로그 변환된 MAE: 0.983
# LGBMRegressor 로그 변환된 MAPE: 69.777
# LGBMRegressor 로그 변환된 MPE: -48.75
# r2-score : 0.283
# 멀티형 에어컨
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 1.1954, 최적 parameter:{'max_depth': 10, 'min_child_samples': 10, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 1.165
# LGBMRegressor 로그 변환된 MSE: 1.357
# LGBMRegressor 로그 변환된 MAE: 0.991
# LGBMRegressor 로그 변환된 MAPE: 49.254
# LGBMRegressor 로그 변환된 MPE: -25.541
# r2-score : 0.274
# 벽걸이 에어컨
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.8461, 최적 parameter:{'max_depth': 10, 'min_child_samples': 3, 'num_leaves': 4}
# LGBMRegressor 로그 변환된 RMSE: 0.817
# LGBMRegressor 로그 변환된 MSE: 0.667
# LGBMRegressor 로그 변환된 MAE: 0.631
# LGBMRegressor 로그 변환된 MAPE: 38.034
# LGBMRegressor 로그 변환된 MPE: -20.096
# r2-score : 0.491
# 벽걸이형 선풍기
#
# ...

# %%
tpr_eval_test
# Out:
#         sm_cat model max_depth num_leaves min_child_samples       MSE  \
# 0      멀티형 에어컨  LGBM         5          8                10  1.438486
# 1      벽걸이 에어컨  LGBM        10          2                10  1.356965
# 2     벽걸이형 선풍기  LGBM        10          4                 3  0.667223
# 3     스탠드형 에어컨  LGBM        10          4                 3  1.635403
# 4      에어컨 리모컨  LGBM        10          2                 5  0.412111
# 5   탁상/USB 선풍기  LGBM        10          2                10  0.713130
# 6      휴대용 선풍기  LGBM        10          2                 5  1.477925
# 7          냉풍기  LGBM        10          2                 5  0.800150
# 8      이동형 에어컨  LGBM        10          2                 3  0.584604
# 9      중대형 에어컨  LGBM        10          2                 3  0.016558
# 10     천장형 에어컨  LGBM        10          2                10  0.138170
# 11        에어커튼  LGBM        10          8                 3  0.054361
# ...

# %% [markdown]
# ## 온도 - 난방

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor
from scipy.stats import skew


for cg_ in ['가스온수기', '난방용 열풍기', '돈풍기', '라디에이터', '보일러', '온수매트', '온열매트',
       '온풍기', '전기온수기', '전기장판', '카페트매트', '컨벡터', '황토매트', '히터']:
    buy_weather_tph_cg = buy_weather_tph[buy_weather_tph['sm_cat'] == cg_]
    
    X_features,y_target,X_train, X_test, y_train, y_test = get_train_test_dataset(buy_weather_tph_cg)
    
    lgbm_params = {'max_depth':[7,5,3,1],'num_leaves':[64,32,16,8,4,2],'min_child_samples':[20,15,10,5,3,1]}
    lgbm_reg = LGBMRegressor()
    best_lgbm, best_params_ = print_best_params(lgbm_reg, lgbm_params)
    
    max_depth= best_params_['max_depth']
    num_leaves= best_params_['num_leaves']
    min_child_samples= best_params_['min_child_samples'] 
    
    lgbm_reg = LGBMRegressor(max_depth=max_depth, min_child_samples= min_child_samples, num_leaves= num_leaves)
    lgbm_reg.fit(X_train, y_train)
    rmse,mse,mae,mape,mpe,r2=get_rmse(lgbm_reg)
    
    tph_eval_test= tph_eval_test.append({'sm_cat': cg_,'model':'LGBM','MSE': mse, 'RMSE': rmse, 'MAE':mae, 'MAPE':mape,
                                     'MPE':mpe,'R2-score':r2,'max_depth':max_depth, 'num_leaves':num_leaves, 'min_child_samples':min_child_samples}, ignore_index=True)
    print(cg_,'\n')
# Out:
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.2038, 최적 parameter:{'max_depth': 7, 'min_child_samples': 15, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.249
# LGBMRegressor 로그 변환된 MSE: 0.062
# LGBMRegressor 로그 변환된 MAE: 0.171
# LGBMRegressor 로그 변환된 MAPE: 17.872
# LGBMRegressor 로그 변환된 MPE: -2.281
# r2-score : -0.077
# 가스온수기
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.3492, 최적 parameter:{'max_depth': 7, 'min_child_samples': 20, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.343
# LGBMRegressor 로그 변환된 MSE: 0.118
# LGBMRegressor 로그 변환된 MAE: 0.274
# LGBMRegressor 로그 변환된 MAPE: 29.264
# LGBMRegressor 로그 변환된 MPE: -10.181
# r2-score : -0.004
# 난방용 열풍기
#
# LGBMRegressor 5 CV 시 최적 평균 RMSE 값: 0.6261, 최적 parameter:{'max_depth': 7, 'min_child_samples': 20, 'num_leaves': 2}
# LGBMRegressor 로그 변환된 RMSE: 0.588
# LGBMRegressor 로그 변환된 MSE: 0.345
# LGBMRegressor 로그 변환된 MAE: 0.481
# LGBMRegressor 로그 변환된 MAPE: 45.275
# LGBMRegressor 로그 변환된 MPE: -26.536
# r2-score : 0.249
# 돈풍기
#
# ...

# %%
tph_eval_test
# Out:
#      sm_cat model max_depth num_leaves min_child_samples       MSE      RMSE  \
# 0     가스온수기  LGBM         7          2                15  0.061872  0.248741
# 1   난방용 열풍기  LGBM         7          2                20  0.117801  0.343221
# 2       돈풍기  LGBM         7          2                20  0.345379  0.587690
# 3     라디에이터  LGBM         7          2                20  0.874324  0.935053
# 4       보일러  LGBM         7          2                10  0.328940  0.573533
# 5      온수매트  LGBM         3         64                20  1.519664  1.232746
# 6      온열매트  LGBM         7          2                20  0.178636  0.422654
# 7       온풍기  LGBM         7         64                15  1.150801  1.072754
# 8     전기온수기  LGBM         7          2                20  0.500237  0.707274
# 9      전기장판  LGBM         7          2                 3  1.042950  1.021249
# 10    카페트매트  LGBM         7          8                10  1.142682  1.068963
# ...

# %%
tpr_eval_test.to_csv('../활용 데이터셋/tpr_eval_lgbm.csv', encoding='cp949',index=False)
tph_eval_test.to_csv('../활용 데이터셋/tph_eval_lgbm.csv', encoding='cp949',index=False)
hm_eval_test.to_csv('../활용 데이터셋/hm_eval_lgbm.csv', encoding='cp949',index=False)
ar_eval_test.to_csv('../활용 데이터셋/ar_eval_lgbm.csv', encoding='cp949',index=False)
